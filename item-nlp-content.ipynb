# %%
import pandas as pd

# %% [markdown]
# Item Based
#
#
# Content Based

# %% [markdown]
# # Cleaning

# %%
movies = pd.read_csv("/kaggle/input/the-movies-dataset/movies_metadata.csv",
                    usecols=["id","overview","title","vote_average","vote_count","release_date"])

# %%
movies.head()
# Out:
#       id                                           overview release_date  \
# 0    862  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1   8844  When siblings Judy and Peter discover an encha...   1995-12-15
# 2  15602  A family wedding reignites the ancient feud be...   1995-12-22
# 3  31357  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 4  11862  Just when George Banks has recovered from his ...   1995-02-10
#
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0

# %%
movies.isnull().sum()
# Out:
# id                0
# overview        954
# release_date     87
# title             6
# vote_average      6
# vote_count        6
# dtype: int64

# %%
movies = movies.dropna()

# %%
movies.isnull().sum()
# Out:
# id              0
# overview        0
# release_date    0
# title           0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
movies.dtypes
# Out:
# id               object
# overview         object
# release_date     object
# title            object
# vote_average    float64
# vote_count      float64
# dtype: object

# %%
movies.duplicated().sum()
# Out:
# 28

# %%
movies = movies.drop_duplicates()

# %%
movies = movies.reset_index(drop=True)

# %%
movies.shape
# Out:
# (44407, 6)

# %%
ratings = pd.read_csv("/kaggle/input/the-movies-dataset/ratings_small.csv")

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %%
ratings["date"] = pd.to_datetime(ratings["timestamp"],unit="s")

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp                date
# 0            1       31     2.5  1260759144 2009-12-14 02:52:24
# 1            1     1029     3.0  1260759179 2009-12-14 02:52:59
# 2            1     1061     3.0  1260759182 2009-12-14 02:53:02
# 3            1     1129     2.0  1260759185 2009-12-14 02:53:05
# 4            1     1172     4.0  1260759205 2009-12-14 02:53:25
# ...        ...      ...     ...         ...                 ...
# 99999      671     6268     2.5  1065579370 2003-10-08 02:16:10
# 100000     671     6269     4.0  1065149201 2003-10-03 02:46:41
# 100001     671     6365     4.0  1070940363 2003-12-09 03:26:03
# 100002     671     6385     2.5  1070979663 2003-12-09 14:21:03
# 100003     671     6565     3.5  1074784724 2004-01-22 15:18:44
#
# [100004 rows x 5 columns]

# %%
ratings = ratings.drop("timestamp",axis=1)

# %%
ratings
# Out:
#         userId  movieId  rating                date
# 0            1       31     2.5 2009-12-14 02:52:24
# 1            1     1029     3.0 2009-12-14 02:52:59
# 2            1     1061     3.0 2009-12-14 02:53:02
# 3            1     1129     2.0 2009-12-14 02:53:05
# 4            1     1172     4.0 2009-12-14 02:53:25
# ...        ...      ...     ...                 ...
# 99999      671     6268     2.5 2003-10-08 02:16:10
# 100000     671     6269     4.0 2003-10-03 02:46:41
# 100001     671     6365     4.0 2003-12-09 03:26:03
# 100002     671     6385     2.5 2003-12-09 14:21:03
# 100003     671     6565     3.5 2004-01-22 15:18:44
#
# [100004 rows x 4 columns]

# %%
ratings.isnull().sum()
# Out:
# userId     0
# movieId    0
# rating     0
# date       0
# dtype: int64

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
movies["id"].nunique()
# Out:
# 44405

# %%
movies = movies.rename(columns={"id":"movieId"})

# %%
movies
# Out:
#       movieId                                           overview release_date  \
# 0         862  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1        8844  When siblings Judy and Peter discover an encha...   1995-12-15
# 2       15602  A family wedding reignites the ancient feud be...   1995-12-22
# 3       31357  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 4       11862  Just when George Banks has recovered from his ...   1995-02-10
# ...       ...                                                ...          ...
# 44402   30840  Yet another version of the classic epic, with ...   1991-05-13
# 44403  111109  An artist struggles to finish his work while a...   2011-11-17
# 44404   67758  When one of her hits goes wrong, a professiona...   2003-08-01
# 44405  227506  In a small town live two brothers, one a minis...   1917-10-21
# 44406  461257  50 years after decriminalisation of homosexual...   2017-06-09
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 44402                   Robin Hood           5.7        26.0
# 44403          Century of Birthing           9.0         3.0
# 44404                     Betrayal           3.8         6.0
# 44405             Satan Triumphant           0.0         0.0
# 44406                     Queerama           0.0         0.0
#
# [44407 rows x 6 columns]

# %%
movies.dtypes
# Out:
# movieId          object
# overview         object
# release_date     object
# title            object
# vote_average    float64
# vote_count      float64
# dtype: object

# %%
ratings.dtypes
# Out:
# userId              int64
# movieId             int64
# rating            float64
# date       datetime64[ns]
# dtype: object

# %%
movies["movieId"] = movies["movieId"].astype("int64")

# %% [markdown]
# # Item Based

# %%
df = pd.merge(movies, ratings, on="movieId", how="inner")

# %%
df
# Out:
#        movieId                                           overview  \
# 0          949  Obsessive master thief, Neil McCauley leads a ...
# 1          949  Obsessive master thief, Neil McCauley leads a ...
# 2          949  Obsessive master thief, Neil McCauley leads a ...
# 3          949  Obsessive master thief, Neil McCauley leads a ...
# 4          949  Obsessive master thief, Neil McCauley leads a ...
# ...        ...                                                ...
# 44818    64197  Plucked from an orphanage as a literal love sl...
# 44819    64197  Plucked from an orphanage as a literal love sl...
# 44820    64197  Plucked from an orphanage as a literal love sl...
# 44821    98604  Masha Krapivina - is yet beautiful, and not th...
# 44822    49280  A band-leader has arranged seven chairs for th...
#
#       release_date                 title  vote_average  vote_count  userId  \
# 0       1995-12-15                  Heat           7.7      1886.0      23
# 1       1995-12-15                  Heat           7.7      1886.0     102
# 2       1995-12-15                  Heat           7.7      1886.0     232
# 3       1995-12-15                  Heat           7.7      1886.0     242
# 4       1995-12-15                  Heat           7.7      1886.0     263
# ...            ...                   ...           ...         ...     ...
# 44818   2007-06-25  Travelling with Pets           6.0         5.0      73
# 44819   2007-06-25  Travelling with Pets           6.0         5.0     544
# 44820   2007-06-25  Travelling with Pets           6.0         5.0     648
# 44821   2012-02-14            Cinderella           4.6         6.0     352
# 44822   1900-01-01      The One-Man Band           6.5        22.0     187
#
#        rating                date
# 0         3.5 2006-05-27 09:11:32
# 1         4.0 2000-04-24 17:55:42
# 2         2.0 2000-04-07 07:31:37
# 3         5.0 2000-04-25 18:53:45
# 4         3.0 2005-06-04 00:56:15
# ...       ...                 ...
# 44818     4.0 2015-09-06 04:24:51
# 44819     5.0 2015-07-01 22:30:19
# 44820     3.5 2009-05-10 10:37:14
# 44821     4.0 2015-01-06 05:26:26
# 44822     5.0 2008-11-30 19:08:28
#
# [44823 rows x 9 columns]

# %%
df["movieId"].nunique()
# Out:
# 2808

# %%
user_title_df = df.groupby(["userId","movieId"])["rating"].mean().unstack().notnull()

# %%
user_title_df
# Out:
# movieId  2       3       5       6       11      12      13      14      \
# userId
# 1         False   False   False   False   False   False   False   False
# 2         False   False   False   False   False   False   False   False
# 3         False   False   False   False   False   False   False   False
# 4         False   False   False   False   False   False   False   False
# 5         False    True   False   False   False   False   False   False
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 667       False   False   False    True    True   False   False   False
# 668       False   False   False   False   False   False   False   False
# 669       False   False   False   False   False   False   False   False
# 670       False   False   False   False   False   False   False   False
# 671       False   False   False   False   False   False   False   False
#
# movieId  15      16      ...  132961  133365  134158  134569  134881  140174  \
# userId                   ...
# 1         False   False  ...   False   False   False   False   False   False
# 2         False   False  ...   False   False   False   False   False   False
# 3         False   False  ...   False   False   False   False   False   False
# 4         False   False  ...   False   False   False   False   False   False
# 5         False   False  ...   False   False   False   False   False   False
# ...         ...     ...  ...     ...     ...     ...     ...     ...     ...
# 667       False    True  ...   False   False   False   False   False   False
# 668       False   False  ...   False   False   False   False   False   False
# 669       False   False  ...   False   False   False   False   False   False
# 670       False   False  ...   False   False   False   False   False   False
# 671       False   False  ...   False   False   False   False   False   False
#
# movieId  142507  148652  158238  160718
# userId
# 1         False   False   False   False
# 2         False   False   False   False
# 3         False   False   False   False
# 4         False   False   False   False
# 5         False   False   False   False
# ...         ...     ...     ...     ...
# 667       False   False   False   False
# 668       False   False   False   False
# 669       False   False   False   False
# 670       False   False   False   False
# 671       False   False   False   False
#
# [671 rows x 2808 columns]

# %%
picked = 1949

# %%
filtered = user_title_df[picked]

# %%
user_title_df_wo = user_title_df.drop(picked,axis=1)

# %%
movies_similarity = user_title_df_wo.corrwith(filtered)

# %%
movies_similarity.sort_values(ascending=False).head(20)
# Out:
# movieId
# 4912     0.561427
# 1948     0.540254
# 1950     0.529912
# 2099     0.492436
# 5747     0.471598
# 1937     0.469822
# 26242    0.469822
# 898      0.455261
# 2132     0.450053
# 7916     0.444532
# 8460     0.444532
# 963      0.444532
# 39231    0.444532
# 4925     0.444532
# 4836     0.444532
# 4274     0.444532
# 7096     0.444532
# 964      0.444532
# 3405     0.439783
# 650      0.439783
# dtype: float64

# %%
movies_similarity = movies_similarity.sort_values(ascending=False).reset_index()
movies_similarity.columns = ["movieId","movies_similarity"]

# %%
movies_similarity
# Out:
#       movieId  movies_similarity
# 0        4912           0.561427
# 1        1948           0.540254
# 2        1950           0.529912
# 3        2099           0.492436
# 4        5747           0.471598
# ...       ...                ...
# 2802      671          -0.027973
# 2803     1249          -0.030554
# 2804      198          -0.032185
# 2805       70          -0.034141
# 2806      196          -0.036753
#
# [2807 rows x 2 columns]

# %% [markdown]
# # Content Based

# %%
movies
# Out:
#        movieId                                           overview  \
# 0          862  Led by Woody, Andy's toys live happily in his ...
# 1         8844  When siblings Judy and Peter discover an encha...
# 2        15602  A family wedding reignites the ancient feud be...
# 3        31357  Cheated on, mistreated and stepped on, the wom...
# 4        11862  Just when George Banks has recovered from his ...
# ...        ...                                                ...
# 44402    30840  Yet another version of the classic epic, with ...
# 44403   111109  An artist struggles to finish his work while a...
# 44404    67758  When one of her hits goes wrong, a professiona...
# 44405   227506  In a small town live two brothers, one a minis...
# 44406   461257  50 years after decriminalisation of homosexual...
#
#       release_date                        title  vote_average  vote_count
# 0       1995-10-30                    Toy Story           7.7      5415.0
# 1       1995-12-15                      Jumanji           6.9      2413.0
# 2       1995-12-22             Grumpier Old Men           6.5        92.0
# 3       1995-12-22            Waiting to Exhale           6.1        34.0
# 4       1995-02-10  Father of the Bride Part II           5.7       173.0
# ...            ...                          ...           ...         ...
# 44402   1991-05-13                   Robin Hood           5.7        26.0
# 44403   2011-11-17          Century of Birthing           9.0         3.0
# 44404   2003-08-01                     Betrayal           3.8         6.0
# 44405   1917-10-21             Satan Triumphant           0.0         0.0
# 44406   2017-06-09                     Queerama           0.0         0.0
#
# [44407 rows x 6 columns]

# %% [markdown]
# kelime = token, kendisi = döküman, tüm kelimeler = corpus

# %%
movies["overview"].loc[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
movies["overview"] = movies["overview"].str.replace(r"[^\w\s]"," ",regex=True).str.replace(r"[\d]"," ",regex=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words="english", min_df = 5)
tfidf_matrix = tfidf.fit_transform(movies["overview"])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(tfidf_matrix,tfidf_matrix)

# %%
index = movies[movies["movieId"] == 1949].index[0]

# %%
movies
# Out:
#        movieId                                           overview  \
# 0          862  Led by Woody  Andy s toys live happily in his ...
# 1         8844  When siblings Judy and Peter discover an encha...
# 2        15602  A family wedding reignites the ancient feud be...
# 3        31357  Cheated on  mistreated and stepped on  the wom...
# 4        11862  Just when George Banks has recovered from his ...
# ...        ...                                                ...
# 44402    30840  Yet another version of the classic epic  with ...
# 44403   111109  An artist struggles to finish his work while a...
# 44404    67758  When one of her hits goes wrong  a professiona...
# 44405   227506  In a small town live two brothers  one a minis...
# 44406   461257     years after decriminalisation of homosexual...
#
#       release_date                        title  vote_average  vote_count
# 0       1995-10-30                    Toy Story           7.7      5415.0
# 1       1995-12-15                      Jumanji           6.9      2413.0
# 2       1995-12-22             Grumpier Old Men           6.5        92.0
# 3       1995-12-22            Waiting to Exhale           6.1        34.0
# 4       1995-02-10  Father of the Bride Part II           5.7       173.0
# ...            ...                          ...           ...         ...
# 44402   1991-05-13                   Robin Hood           5.7        26.0
# 44403   2011-11-17          Century of Birthing           9.0         3.0
# 44404   2003-08-01                     Betrayal           3.8         6.0
# 44405   1917-10-21             Satan Triumphant           0.0         0.0
# 44406   2017-06-09                     Queerama           0.0         0.0
#
# [44407 rows x 6 columns]

# %%
pd.DataFrame(similarity[index], columns=["similarity"])
# Out:
#        similarity
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 44402    0.021734
# 44403    0.000000
# 44404    0.000000
# 44405    0.007536
# 44406    0.020335
#
# [44407 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

def hybrid(movieid, how_many=5):
    # item-based
    filtered = user_title_df[picked]
    user_title_df_wo = user_title_df.drop(picked,axis=1)
    movies_similarity = user_title_df_wo.corrwith(filtered).reset_index()
    movies_similarity.columns = ["movieId","movies_similarity"]
    movies_similarity["movies_similarity"] = MinMaxScaler().fit_transform(movies_similarity[["movies_similarity"]])
    
    #content-based
    index = movies[movies["movieId"] == movieid].index[0]
    content_similarity = pd.DataFrame(dict(zip(similarity[index],movies["movieId"])).items(), columns=["cosine_similarity","movieId"])
    content_similarity["cosine_similarity"] = MinMaxScaler().fit_transform(content_similarity[["cosine_similarity"]])
    
    #merge
    merged = pd.merge(movies_similarity,content_similarity,on = "movieId", how="inner")
    merged["hybrid"] = merged["movies_similarity"] * merged["cosine_similarity"]
    
    #hybrid
    merged = merged.sort_values(by="hybrid", ascending=False)
    
    last_df = pd.merge(merged,movies,on="movieId", how="inner")[["title","hybrid","movieId","release_date"]].head(how_many)
    return last_df

# %%
hybrid(1949, how_many=5)
# Out:
#                          title    hybrid  movieId release_date
# 0  Seven Blood-Stained Orchids  0.089864     3699   1972-06-30
# 1                   The Pledge  0.070376     5955   2001-01-09
# 2                   Antibodies  0.069062     8332   2005-04-24
# 3                        Mercy  0.059701     5247   2000-02-11
# 4                   Nightwatch  0.059638     6498   1994-02-25
